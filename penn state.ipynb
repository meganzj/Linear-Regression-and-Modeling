# %%
import pandas as pd
from pandas.plotting import scatter_matrix

# %%
data = pd.read_csv('iq.txt', delimiter = "\t" )

# %%
data.head()
# Out:
#    PIQ   Brain  Height  Weight
# 0  124   81.69    64.5     118
# 1  150  103.84    73.3     143
# 2  128   96.54    68.8     172
# 3  134   95.15    65.0     147
# 4  110   92.88    69.0     146

# %%
scatter_matrix(data, diagonal = 'kde')
# Out:
# array([[<Axes: xlabel='PIQ', ylabel='PIQ'>,
#         <Axes: xlabel='Brain', ylabel='PIQ'>,
#         <Axes: xlabel='Height', ylabel='PIQ'>,
#         <Axes: xlabel='Weight', ylabel='PIQ'>],
#        [<Axes: xlabel='PIQ', ylabel='Brain'>,
#         <Axes: xlabel='Brain', ylabel='Brain'>,
#         <Axes: xlabel='Height', ylabel='Brain'>,
#         <Axes: xlabel='Weight', ylabel='Brain'>],
#        [<Axes: xlabel='PIQ', ylabel='Height'>,
#         <Axes: xlabel='Brain', ylabel='Height'>,
#         <Axes: xlabel='Height', ylabel='Height'>,
#         <Axes: xlabel='Weight', ylabel='Height'>],
#        [<Axes: xlabel='PIQ', ylabel='Weight'>,
#         <Axes: xlabel='Brain', ylabel='Weight'>,
#         <Axes: xlabel='Height', ylabel='Weight'>,
#         <Axes: xlabel='Weight', ylabel='Weight'>]], dtype=object)
